# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
import time
import datetime
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, confusion_matrix
import lightgbm as lgb
from math import radians, cos, sin, asin, sqrt
from tqdm import tqdm, tqdm_notebook
import pickle
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import math
from itertools import combinations
from sklearn.preprocessing import LabelEncoder
from gensim.models import Word2Vec
import json
import gc
import re
warnings.filterwarnings('ignore')
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
train = pd.read_csv('../data/first_round_training_data.csv')
test = pd.read_csv('../data/first_round_testing_data.csv')

# %%
len(train),len(test)
# Out:
# (6000, 6000)

# %%
features = [c for c in test.columns if c!='Group']
cat_feats = ['Attribute4',
'Attribute5',
'Attribute6',
'Attribute7',
'Attribute8',
'Attribute9',
'Attribute10',
'Parameter5',
'Parameter6',
'Parameter7',
'Parameter8',
'Parameter9',
'Parameter10']

use_cate = [c for c in cat_feats if 'Para' in c]  #使用到的6个变量
col_only_train = [c for c in test.columns if c != 'Group']  #训练集中的所有变量
all_feat = [c for c in train.columns if c != 'Quality_label']  #数据的所有特征
data = pd.concat([train,test])

def nnq_encode(data,en_col,use_col):
    data[en_col + '_nnq_of_' + use_col] = data[en_col].map( data.groupby([en_col])[use_col].nunique() )
    features.append( en_col + '_nnq_of_' + use_col )
    return data

for en_col in use_cate:
    for use_col in cat_feats:
        if en_col != use_col:
            data = nnq_encode(data,en_col,use_col)
# for en_col in use_cate:
#     for use_col in use_cate:
#         if en_col != use_col:
#             colname =  en_col +'_count_' + use_col
#             features.append( colname)
#             data[ colname] = data[en_col].astype(str) + "|" + data[use_col].astype(str)
#             data[ colname] = data.groupby([ colname ])[colname].transform('count')
# for en_col in use_cate:
#     for use_col in all_feat:
#         if en_col != use_col:
#             colname =  en_col +'_mean_' + use_col
#             features.append( colname)
#             data[ colname] = data[en_col].map( data.groupby([en_col])[use_col].mean() )
#             colname =  en_col +'_std_' + use_col
#             features.append( colname)
#             data[ colname] = data[en_col].map( data.groupby([en_col])[use_col].std() )

# %%
classMap = {'Excellent':0,
'Good':1,
'Pass':2,
'Fail':3,}
tr_index = ~data.Quality_label.isnull()
train_df = data[tr_index][features +['Quality_label']].reset_index(drop=True)
train_df['Quality_label'] = train_df['Quality_label'].map(classMap)

test_df = data[~tr_index].reset_index(drop=True)
id_test = test_df.Group.values


X_train = train_df[features]    
y = train_df.Quality_label
X_test = test_df[features]
del train,test
del train_df,test_df
gc.collect()
# Out:
# 213

# %%
X_train[:10]
# Out:
#      Parameter1  Parameter10  Parameter2  Parameter3  Parameter4  Parameter5  \
# 0      0.001660     1.010385    0.591013  147.608373   38.186345    0.000421
# 1      1.601749     1.010385    0.015052    0.035864   51.130326    0.000909
# 2      0.098039     1.010385   69.233685    0.080920    0.112265    0.000909
# 3     18.181860     1.010385    0.047325    0.018061    1.098102    0.000909
# 4      0.012085     1.010385    0.008749    0.005509  524.327396    0.000909
# 5      0.004062     1.010385   14.556483    0.786945    0.010545    0.000525
# 6      0.438449     0.010192    1.232559    2.882699    0.610757    1.600654
# 7  48159.917401     0.010192    0.002987   14.863813    0.063287    1.434060
# 8      1.456601     0.010192   52.381578   20.625283  366.074831    1.434060
# 9      0.000109     0.010192    4.784654   31.916672   20.672388    1.284806
#
#    Parameter6   Parameter7  Parameter8  Parameter9  \
# 0    0.000612  2286.523413    0.035407    0.593081
# 1    0.002397  2286.523413    0.035407    0.593081
# 2    0.001972  2286.523413    0.035407    0.593081
# 3    0.002397  2286.523413    0.035407    0.593081
# 4    0.002397  2286.523413    0.035407    0.593081
# 5    0.001623  2286.523413    0.035407    0.593081
# 6    0.464037     0.600827   17.850021    0.051850
# 7    0.314162     0.600827   17.850021    0.051850
# 8    0.258497     0.600827   17.850021    0.051850
# 9    0.175007     0.600827   17.850021    0.051850
#
#                ...                Parameter10_nnq_of_Attribute6  \
# 0              ...                                          122
# 1              ...                                          122
# 2              ...                                          122
# 3              ...                                          122
# 4              ...                                          122
# 5              ...                                          122
# 6              ...                                           51
# 7              ...                                           51
# 8              ...                                           51
# 9              ...                                           51
#
#    Parameter10_nnq_of_Attribute7  Parameter10_nnq_of_Attribute8  \
# 0                            137                            137
# 1                            137                            137
# 2                            137                            137
# 3                            137                            137
# 4                            137                            137
# 5                            137                            137
# 6                             60                             52
# 7                             60                             52
# 8                             60                             52
# 9                             60                             52
#
#    Parameter10_nnq_of_Attribute9  Parameter10_nnq_of_Attribute10  \
# 0                            135                             131
# 1                            135                             131
# 2                            135                             131
# 3                            135                             131
# 4                            135                             131
# 5                            135                             131
# 6                             61                              60
# 7                             61                              60
# 8                             61                              60
# 9                             61                              60
#
#    Parameter10_nnq_of_Parameter5  Parameter10_nnq_of_Parameter6  \
# 0                             63                             52
# 1                             63                             52
# 2                             63                             52
# 3                             63                             52
# 4                             63                             52
# 5                             63                             52
# 6                             36                             35
# 7                             36                             35
# 8                             36                             35
# 9                             36                             35
#
#    Parameter10_nnq_of_Parameter7  Parameter10_nnq_of_Parameter8  \
# 0                             10                             15
# 1                             10                             15
# 2                             10                             15
# 3                             10                             15
# 4                             10                             15
# 5                             10                             15
# 6                              6                              7
# 7                              6                              7
# 8                              6                              7
# 9                              6                              7
#
#    Parameter10_nnq_of_Parameter9
# 0                             11
# 1                             11
# 2                             11
# 3                             11
# 4                             11
# 5                             11
# 6                              8
# 7                              8
# 8                              8
# 9                              8
#
# [10 rows x 82 columns]

# %%
lgb_paras = {
        'objective': 'multiclass',
        'metric': 'multi_logloss',
        'learning_rate': 0.01,
        'num_leaves': 32,
        # 'lambda_l1': 0.01,
        # 'lambda_l2': 10,
        'num_class': 4,
        'max_depth': -1,
        'seed': 2019,
        'feature_fraction': 0.8,
        #         'bagging_fraction': 0.8,
        #         'bagging_freq': 4,
        'verbose': 1
#         'device': gpu
    }
from sklearn.metrics import f1_score, confusion_matrix
all_preads = []
skf = StratifiedKFold(n_splits=5, random_state=2019, shuffle=True)
def f1_weighted(preds, train_data):
    y_true = train_data.label
    preds = np.argmax(preds.reshape(4, -1), axis=0)
    score = f1_score(y_true, preds, average='weighted')
    return 'f1_weighted', score, True
evals_result = {}
for index, (train_index, test_index) in enumerate(skf.split(X_train, y)):
    train_x, test_x, train_y, test_y = X_train[features].iloc[train_index], X_train[features].iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    dtrain = lgb.Dataset(train_x, train_y)

    dvalid = lgb.Dataset(test_x, test_y)
#     clf = lgb.train(
#         params=lgb_paras,
#         train_set=dtrain,
#         num_boost_round=10000,
#         valid_sets=[dtrain, dvalid],
#         evals_result=evals_result,
#         early_stopping_rounds=100,
#         valid_names=["train", "valid"],
#         # categorical_feature=cate_cols,
#         verbose_eval=100)
    
    lgb_modelall = lgb.train(lgb_paras, dtrain,
                             valid_sets=[dtrain, dvalid],
                             num_boost_round=1000,
                             early_stopping_rounds=100,
                             valid_names=["train", "valid"],
                             evals_result=evals_result,
                             verbose_eval=50,
                             feval=f1_weighted)
    pred = lgb_modelall.predict(X_test)
    all_preads.append( pred )
# Out:
# Training until validation scores don't improve for 100 rounds.
# [50]	train's multi_logloss: 1.16559	train's f1_weighted: 0.345257	valid's multi_logloss: 1.20535	valid's f1_weighted: 0.30445
# [100]	train's multi_logloss: 1.07954	train's f1_weighted: 0.568834	valid's multi_logloss: 1.1529	valid's f1_weighted: 0.449902
# [150]	train's multi_logloss: 1.02047	train's f1_weighted: 0.610414	valid's multi_logloss: 1.12669	valid's f1_weighted: 0.490659
# [200]	train's multi_logloss: 0.975448	train's f1_weighted: 0.63445	valid's multi_logloss: 1.11296	valid's f1_weighted: 0.492665
# [250]	train's multi_logloss: 0.938544	train's f1_weighted: 0.645356	valid's multi_logloss: 1.10624	valid's f1_weighted: 0.495564
# [300]	train's multi_logloss: 0.905144	train's f1_weighted: 0.657716	valid's multi_logloss: 1.10322	valid's f1_weighted: 0.497226
# [350]	train's multi_logloss: 0.875017	train's f1_weighted: 0.675987	valid's multi_logloss: 1.10164	valid's f1_weighted: 0.498719
# Early stopping, best iteration is:
# [287]	train's multi_logloss: 0.91356	train's f1_weighted: 0.654598	valid's multi_logloss: 1.10395	valid's f1_weighted: 0.501985
# Training until validation scores don't improve for 100 rounds.
# [50]	train's multi_logloss: 1.16405	train's f1_weighted: 0.330055	valid's multi_logloss: 1.2097	valid's f1_weighted: 0.281582
# [100]	train's multi_logloss: 1.07694	train's f1_weighted: 0.568987	valid's multi_logloss: 1.16122	valid's f1_weighted: 0.439899
# [150]	train's multi_logloss: 1.01822	train's f1_weighted: 0.62406	valid's multi_logloss: 1.13778	valid's f1_weighted: 0.473342
# [200]	train's multi_logloss: 0.972541	train's f1_weighted: 0.648907	valid's multi_logloss: 1.12575	valid's f1_weighted: 0.491307
# [250]	train's multi_logloss: 0.934544	train's f1_weighted: 0.66271	valid's multi_logloss: 1.1194	valid's f1_weighted: 0.496731
# [300]	train's multi_logloss: 0.901484	train's f1_weighted: 0.678873	valid's multi_logloss: 1.11546	valid's f1_weighted: 0.496505
# [350]	train's multi_logloss: 0.871442	train's f1_weighted: 0.691243	valid's multi_logloss: 1.11439	valid's f1_weighted: 0.501372
# [400]	train's multi_logloss: 0.844402	train's f1_weighted: 0.705909	valid's multi_logloss: 1.1145	valid's f1_weighted: 0.500387
# Early stopping, best iteration is:
# [342]	train's multi_logloss: 0.876116	train's f1_weighted: 0.689122	valid's multi_logloss: 1.11451	valid's f1_weighted: 0.503966
# Training until validation scores don't improve for 100 rounds.
# [50]	train's multi_logloss: 1.16672	train's f1_weighted: 0.329451	valid's multi_logloss: 1.20654	valid's f1_weighted: 0.309157
# [100]	train's multi_logloss: 1.08168	train's f1_weighted: 0.555821	valid's multi_logloss: 1.15517	valid's f1_weighted: 0.459669
# [150]	train's multi_logloss: 1.02315	train's f1_weighted: 0.606374	valid's multi_logloss: 1.12901	valid's f1_weighted: 0.491404
# [200]	train's multi_logloss: 0.977544	train's f1_weighted: 0.635086	valid's multi_logloss: 1.11452	valid's f1_weighted: 0.504658
# [250]	train's multi_logloss: 0.939409	train's f1_weighted: 0.652215	valid's multi_logloss: 1.10685	valid's f1_weighted: 0.513761
# [300]	train's multi_logloss: 0.905997	train's f1_weighted: 0.669699	valid's multi_logloss: 1.10334	valid's f1_weighted: 0.515655
# [350]	train's multi_logloss: 0.876032	train's f1_weighted: 0.689052	valid's multi_logloss: 1.10131	valid's f1_weighted: 0.514709
# Early stopping, best iteration is:
# [283]	train's multi_logloss: 0.916913	train's f1_weighted: 0.663194	valid's multi_logloss: 1.10452	valid's f1_weighted: 0.518301
# Training until validation scores don't improve for 100 rounds.
# [50]	train's multi_logloss: 1.16602	train's f1_weighted: 0.341687	valid's multi_logloss: 1.20561	valid's f1_weighted: 0.297625
# [100]	train's multi_logloss: 1.08014	train's f1_weighted: 0.55897	valid's multi_logloss: 1.15466	valid's f1_weighted: 0.433059
# [150]	train's multi_logloss: 1.02144	train's f1_weighted: 0.621625	valid's multi_logloss: 1.12874	valid's f1_weighted: 0.477947
# [200]	train's multi_logloss: 0.975398	train's f1_weighted: 0.649907	valid's multi_logloss: 1.11461	valid's f1_weighted: 0.488201
# [250]	train's multi_logloss: 0.937145	train's f1_weighted: 0.661896	valid's multi_logloss: 1.10666	valid's f1_weighted: 0.502546
# [300]	train's multi_logloss: 0.903435	train's f1_weighted: 0.678449	valid's multi_logloss: 1.10202	valid's f1_weighted: 0.503729
# [350]	train's multi_logloss: 0.872901	train's f1_weighted: 0.69462	valid's multi_logloss: 1.10004	valid's f1_weighted: 0.504792
# [400]	train's multi_logloss: 0.845528	train's f1_weighted: 0.70768	valid's multi_logloss: 1.10025	valid's f1_weighted: 0.49875
# Early stopping, best iteration is:
# [335]	train's multi_logloss: 0.88166	train's f1_weighted: 0.689356	valid's multi_logloss: 1.10044	valid's f1_weighted: 0.506688
# Training until validation scores don't improve for 100 rounds.
# [50]	train's multi_logloss: 1.16845	train's f1_weighted: 0.313328	valid's multi_logloss: 1.20205	valid's f1_weighted: 0.269616
# [100]	train's multi_logloss: 1.08418	train's f1_weighted: 0.550338	valid's multi_logloss: 1.14603	valid's f1_weighted: 0.46147
# [150]	train's multi_logloss: 1.02663	train's f1_weighted: 0.621133	valid's multi_logloss: 1.11609	valid's f1_weighted: 0.500456
# [200]	train's multi_logloss: 0.981994	train's f1_weighted: 0.633993	valid's multi_logloss: 1.10123	valid's f1_weighted: 0.516739
# [250]	train's multi_logloss: 0.944489	train's f1_weighted: 0.650321	valid's multi_logloss: 1.09235	valid's f1_weighted: 0.520099
# [300]	train's multi_logloss: 0.91118	train's f1_weighted: 0.664887	valid's multi_logloss: 1.08785	valid's f1_weighted: 0.518305
# [350]	train's multi_logloss: 0.881009	train's f1_weighted: 0.681128	valid's multi_logloss: 1.0852	valid's f1_weighted: 0.517309
# Early stopping, best iteration is:
# [267]	train's multi_logloss: 0.932822	train's f1_weighted: 0.651342	valid's multi_logloss: 1.09038	valid's f1_weighted: 0.524972

# %%
mean_pread = np.mean(all_preads,axis=0)
cols = ['Excellent ratio','Good ratio','Pass ratio','Fail ratio']

sub_prob  = pd.DataFrame(mean_pread,columns=cols)
len(sub_prob),len(id_test)
sub_prob['Group'] = id_test

sub_prob['Group'] = sub_prob['Group'].map(int)
sub_prob = sub_prob.groupby([ 'Group'])[cols].median().reset_index()

sub_prob.to_csv('../submission/lgb_3rd.csv',index=False)

# %%
all_preads[0][0]
# Out:
# array([0.19531831, 0.38796819, 0.24127368, 0.17543982])

# %%
features
# Out:
# ['Parameter1',
#  'Parameter10',
#  'Parameter2',
#  'Parameter3',
#  'Parameter4',
#  'Parameter5',
#  'Parameter6',
#  'Parameter7',
#  'Parameter8',
#  'Parameter9',
#  'Parameter5_nnq_of_Attribute4',
#  'Parameter5_nnq_of_Attribute5',
#  'Parameter5_nnq_of_Attribute6',
#  'Parameter5_nnq_of_Attribute7',
#  'Parameter5_nnq_of_Attribute8',
#  'Parameter5_nnq_of_Attribute9',
#  'Parameter5_nnq_of_Attribute10',
#  'Parameter5_nnq_of_Parameter6',
#  'Parameter5_nnq_of_Parameter7',
#  'Parameter5_nnq_of_Parameter8',
#  'Parameter5_nnq_of_Parameter9',
#  'Parameter5_nnq_of_Parameter10',
#  'Parameter6_nnq_of_Attribute4',
#  'Parameter6_nnq_of_Attribute5',
#  'Parameter6_nnq_of_Attribute6',
#  'Parameter6_nnq_of_Attribute7',
#  'Parameter6_nnq_of_Attribute8',
#  'Parameter6_nnq_of_Attribute9',
#  'Parameter6_nnq_of_Attribute10',
#  'Parameter6_nnq_of_Parameter5',
#  'Parameter6_nnq_of_Parameter7',
#  'Parameter6_nnq_of_Parameter8',
#  'Parameter6_nnq_of_Parameter9',
#  'Parameter6_nnq_of_Parameter10',
#  'Parameter7_nnq_of_Attribute4',
#  'Parameter7_nnq_of_Attribute5',
#  'Parameter7_nnq_of_Attribute6',
#  'Parameter7_nnq_of_Attribute7',
#  'Parameter7_nnq_of_Attribute8',
#  'Parameter7_nnq_of_Attribute9',
#  'Parameter7_nnq_of_Attribute10',
#  'Parameter7_nnq_of_Parameter5',
#  'Parameter7_nnq_of_Parameter6',
#  'Parameter7_nnq_of_Parameter8',
#  'Parameter7_nnq_of_Parameter9',
#  'Parameter7_nnq_of_Parameter10',
#  'Parameter8_nnq_of_Attribute4',
#  'Parameter8_nnq_of_Attribute5',
#  'Parameter8_nnq_of_Attribute6',
#  'Parameter8_nnq_of_Attribute7',
#  'Parameter8_nnq_of_Attribute8',
#  'Parameter8_nnq_of_Attribute9',
#  'Parameter8_nnq_of_Attribute10',
#  'Parameter8_nnq_of_Parameter5',
#  'Parameter8_nnq_of_Parameter6',
#  'Parameter8_nnq_of_Parameter7',
#  'Parameter8_nnq_of_Parameter9',
#  'Parameter8_nnq_of_Parameter10',
#  'Parameter9_nnq_of_Attribute4',
#  'Parameter9_nnq_of_Attribute5',
#  'Parameter9_nnq_of_Attribute6',
#  'Parameter9_nnq_of_Attribute7',
#  'Parameter9_nnq_of_Attribute8',
#  'Parameter9_nnq_of_Attribute9',
#  'Parameter9_nnq_of_Attribute10',
#  'Parameter9_nnq_of_Parameter5',
#  'Parameter9_nnq_of_Parameter6',
#  'Parameter9_nnq_of_Parameter7',
#  'Parameter9_nnq_of_Parameter8',
#  'Parameter9_nnq_of_Parameter10',
#  'Parameter10_nnq_of_Attribute4',
#  'Parameter10_nnq_of_Attribute5',
#  'Parameter10_nnq_of_Attribute6',
#  'Parameter10_nnq_of_Attribute7',
#  'Parameter10_nnq_of_Attribute8',
#  'Parameter10_nnq_of_Attribute9',
#  'Parameter10_nnq_of_Attribute10',
#  'Parameter10_nnq_of_Parameter5',
#  'Parameter10_nnq_of_Parameter6',
#  'Parameter10_nnq_of_Parameter7',
#  'Parameter10_nnq_of_Parameter8',
#  'Parameter10_nnq_of_Parameter9']
