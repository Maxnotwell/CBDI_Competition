# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
import time
import datetime
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, confusion_matrix
import lightgbm as lgb
from math import radians, cos, sin, asin, sqrt
from tqdm import tqdm, tqdm_notebook
import pickle
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import math
from itertools import combinations
from sklearn.preprocessing import LabelEncoder
from gensim.models import Word2Vec
import json
import gc
import re
warnings.filterwarnings('ignore')
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
train = pd.read_csv('../data/first_round_training_data.csv')
test = pd.read_csv('../data/first_round_testing_data.csv')

# %%
len(train),len(test)
# Out:
# (6000, 6000)

# %%
features = [c for c in test.columns if c!='Group']
cat_feats = ['Attribute4',
'Attribute5',
'Attribute6',
'Attribute7',
'Attribute8',
'Attribute9',
'Attribute10',
'Parameter5',
'Parameter6',
'Parameter7',
'Parameter8',
'Parameter9',
'Parameter10']

use_cate = [c for c in cat_feats if 'Para' in c]  #使用到的6个变量
col_only_train = [c for c in test.columns if c != 'Group']  #训练集中的所有变量
all_feat = [c for c in train.columns if c != 'Quality_label']  #数据的所有特征
data = pd.concat([train,test])

def nnq_encode(data,en_col,use_col):
    data[en_col + '_nnq_of_' + use_col] = data[en_col].map( data.groupby([en_col])[use_col].nunique() )
    features.append( en_col + '_nnq_of_' + use_col )
    return data

# for en_col in use_cate:
#     for use_col in cat_feats:
#         if en_col != use_col:
#             data = nnq_encode(data,en_col,use_col)
# for en_col in use_cate:
#     for use_col in use_cate:
#         if en_col != use_col:
#             colname =  en_col +'_count_' + use_col
#             features.append( colname)
#             data[ colname] = data[en_col].astype(str) + "|" + data[use_col].astype(str)
#             data[ colname] = data.groupby([ colname ])[colname].transform('count')
# for en_col in use_cate:
#     for use_col in all_feat:
#         if en_col != use_col:
#             colname =  en_col +'_mean_' + use_col
#             features.append( colname)
#             data[ colname] = data[en_col].map( data.groupby([en_col])[use_col].mean() )
#             colname =  en_col +'_std_' + use_col
#             features.append( colname)
#             data[ colname] = data[en_col].map( data.groupby([en_col])[use_col].std() )

# %%
classMap = {'Excellent':0,
'Good':1,
'Pass':2,
'Fail':3,}
tr_index = ~data.Quality_label.isnull()
train_df = data[tr_index][features +['Quality_label']].reset_index(drop=True)
train_df['Quality_label'] = train_df['Quality_label'].map(classMap)

test_df = data[~tr_index].reset_index(drop=True)
id_test = test_df.Group.values


X_train = train_df[features]    
y = train_df.Quality_label
X_test = test_df[features]
del train,test
del train_df,test_df
gc.collect()
# Out:
# 87

# %%
X_train[:10]
# Out:
#      Parameter1  Parameter10  Parameter2  Parameter3  Parameter4  Parameter5  \
# 0      0.001660     1.010385    0.591013  147.608373   38.186345    0.000421
# 1      1.601749     1.010385    0.015052    0.035864   51.130326    0.000909
# 2      0.098039     1.010385   69.233685    0.080920    0.112265    0.000909
# 3     18.181860     1.010385    0.047325    0.018061    1.098102    0.000909
# 4      0.012085     1.010385    0.008749    0.005509  524.327396    0.000909
# 5      0.004062     1.010385   14.556483    0.786945    0.010545    0.000525
# 6      0.438449     0.010192    1.232559    2.882699    0.610757    1.600654
# 7  48159.917401     0.010192    0.002987   14.863813    0.063287    1.434060
# 8      1.456601     0.010192   52.381578   20.625283  366.074831    1.434060
# 9      0.000109     0.010192    4.784654   31.916672   20.672388    1.284806
#
#    Parameter6   Parameter7  Parameter8  Parameter9
# 0    0.000612  2286.523413    0.035407    0.593081
# 1    0.002397  2286.523413    0.035407    0.593081
# 2    0.001972  2286.523413    0.035407    0.593081
# 3    0.002397  2286.523413    0.035407    0.593081
# 4    0.002397  2286.523413    0.035407    0.593081
# 5    0.001623  2286.523413    0.035407    0.593081
# 6    0.464037     0.600827   17.850021    0.051850
# 7    0.314162     0.600827   17.850021    0.051850
# 8    0.258497     0.600827   17.850021    0.051850
# 9    0.175007     0.600827   17.850021    0.051850

# %%
lgb_paras = {
        'objective': 'multiclass',
        'metric': 'multi_logloss',
        'learning_rate': 0.01,
        'num_leaves': 32,
        # 'lambda_l1': 0.01,
        # 'lambda_l2': 10,
        'num_class': 4,
        'max_depth': -1,
        'seed': 2019,
        'feature_fraction': 0.8,
        #         'bagging_fraction': 0.8,
        #         'bagging_freq': 4,
        'verbose': 1
#         'device': gpu
    }
from sklearn.metrics import f1_score, confusion_matrix
all_preads = []
skf = StratifiedKFold(n_splits=5, random_state=2019, shuffle=True)
def f1_weighted(preds, train_data):
    y_true = train_data.label
    preds = np.argmax(preds.reshape(4, -1), axis=0)
    score = f1_score(y_true, preds, average='weighted')
    return 'f1_weighted', score, True
evals_result = {}
for index, (train_index, test_index) in enumerate(skf.split(X_train, y)):
    train_x, test_x, train_y, test_y = X_train[features].iloc[train_index], X_train[features].iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    dtrain = lgb.Dataset(train_x, train_y)

    dvalid = lgb.Dataset(test_x, test_y)
#     clf = lgb.train(
#         params=lgb_paras,
#         train_set=dtrain,
#         num_boost_round=10000,
#         valid_sets=[dtrain, dvalid],
#         evals_result=evals_result,
#         early_stopping_rounds=100,
#         valid_names=["train", "valid"],
#         # categorical_feature=cate_cols,
#         verbose_eval=100)
    
    lgb_modelall = lgb.train(lgb_paras, dtrain,
                             valid_sets=[dtrain, dvalid],
                             num_boost_round=1000,
                             early_stopping_rounds=100,
                             valid_names=["train", "valid"],
                             evals_result=evals_result,
                             verbose_eval=50,
                             feval=f1_weighted)
    pred = lgb_modelall.predict(X_test)
    all_preads.append( pred )
# Out:
# Training until validation scores don't improve for 100 rounds.
# [50]	train's multi_logloss: 1.17429	train's f1_weighted: 0.298003	valid's multi_logloss: 1.21025	valid's f1_weighted: 0.263807
# [100]	train's multi_logloss: 1.09496	train's f1_weighted: 0.545342	valid's multi_logloss: 1.16197	valid's f1_weighted: 0.441636
# [150]	train's multi_logloss: 1.0392	train's f1_weighted: 0.59546	valid's multi_logloss: 1.13435	valid's f1_weighted: 0.476635
# [200]	train's multi_logloss: 0.998146	train's f1_weighted: 0.618237	valid's multi_logloss: 1.11963	valid's f1_weighted: 0.496565
# [250]	train's multi_logloss: 0.963847	train's f1_weighted: 0.63263	valid's multi_logloss: 1.11218	valid's f1_weighted: 0.494391
# [300]	train's multi_logloss: 0.934558	train's f1_weighted: 0.645829	valid's multi_logloss: 1.10844	valid's f1_weighted: 0.497537
# [350]	train's multi_logloss: 0.908014	train's f1_weighted: 0.657797	valid's multi_logloss: 1.10596	valid's f1_weighted: 0.492839
# Early stopping, best iteration is:
# [272]	train's multi_logloss: 0.950439	train's f1_weighted: 0.635864	valid's multi_logloss: 1.11053	valid's f1_weighted: 0.498975
# Training until validation scores don't improve for 100 rounds.
# [50]	train's multi_logloss: 1.17405	train's f1_weighted: 0.295894	valid's multi_logloss: 1.21601	valid's f1_weighted: 0.263378
# [100]	train's multi_logloss: 1.09444	train's f1_weighted: 0.539307	valid's multi_logloss: 1.16854	valid's f1_weighted: 0.431353
# [150]	train's multi_logloss: 1.03832	train's f1_weighted: 0.593431	valid's multi_logloss: 1.14277	valid's f1_weighted: 0.464331
# [200]	train's multi_logloss: 0.996615	train's f1_weighted: 0.622972	valid's multi_logloss: 1.1298	valid's f1_weighted: 0.478332
# [250]	train's multi_logloss: 0.961682	train's f1_weighted: 0.640101	valid's multi_logloss: 1.12231	valid's f1_weighted: 0.484762
# [300]	train's multi_logloss: 0.93171	train's f1_weighted: 0.653792	valid's multi_logloss: 1.11814	valid's f1_weighted: 0.490674
# [350]	train's multi_logloss: 0.905793	train's f1_weighted: 0.665191	valid's multi_logloss: 1.11628	valid's f1_weighted: 0.492866
# [400]	train's multi_logloss: 0.881315	train's f1_weighted: 0.679989	valid's multi_logloss: 1.11576	valid's f1_weighted: 0.494805
# [450]	train's multi_logloss: 0.858867	train's f1_weighted: 0.695178	valid's multi_logloss: 1.11588	valid's f1_weighted: 0.494098
# [500]	train's multi_logloss: 0.838228	train's f1_weighted: 0.704982	valid's multi_logloss: 1.11756	valid's f1_weighted: 0.490844
# Early stopping, best iteration is:
# [413]	train's multi_logloss: 0.875328	train's f1_weighted: 0.684339	valid's multi_logloss: 1.11557	valid's f1_weighted: 0.497117
# Training until validation scores don't improve for 100 rounds.
# [50]	train's multi_logloss: 1.17562	train's f1_weighted: 0.299682	valid's multi_logloss: 1.21141	valid's f1_weighted: 0.276505
# [100]	train's multi_logloss: 1.09636	train's f1_weighted: 0.535355	valid's multi_logloss: 1.16434	valid's f1_weighted: 0.446573
# [150]	train's multi_logloss: 1.04056	train's f1_weighted: 0.593327	valid's multi_logloss: 1.13735	valid's f1_weighted: 0.490422
# [200]	train's multi_logloss: 0.99855	train's f1_weighted: 0.61896	valid's multi_logloss: 1.12376	valid's f1_weighted: 0.500584
# [250]	train's multi_logloss: 0.96365	train's f1_weighted: 0.638029	valid's multi_logloss: 1.11738	valid's f1_weighted: 0.505539
# [300]	train's multi_logloss: 0.933879	train's f1_weighted: 0.654748	valid's multi_logloss: 1.11528	valid's f1_weighted: 0.499418
# [350]	train's multi_logloss: 0.906948	train's f1_weighted: 0.670092	valid's multi_logloss: 1.11428	valid's f1_weighted: 0.501896
# Early stopping, best iteration is:
# [263]	train's multi_logloss: 0.95562	train's f1_weighted: 0.641977	valid's multi_logloss: 1.11653	valid's f1_weighted: 0.507183
# Training until validation scores don't improve for 100 rounds.
# [50]	train's multi_logloss: 1.17547	train's f1_weighted: 0.286349	valid's multi_logloss: 1.20734	valid's f1_weighted: 0.279731
# [100]	train's multi_logloss: 1.09717	train's f1_weighted: 0.540506	valid's multi_logloss: 1.15842	valid's f1_weighted: 0.454604
# [150]	train's multi_logloss: 1.04236	train's f1_weighted: 0.596175	valid's multi_logloss: 1.13103	valid's f1_weighted: 0.481157
# [200]	train's multi_logloss: 1.00085	train's f1_weighted: 0.616824	valid's multi_logloss: 1.1158	valid's f1_weighted: 0.492882
# [250]	train's multi_logloss: 0.965959	train's f1_weighted: 0.632796	valid's multi_logloss: 1.10632	valid's f1_weighted: 0.504542
# [300]	train's multi_logloss: 0.935751	train's f1_weighted: 0.652528	valid's multi_logloss: 1.10139	valid's f1_weighted: 0.512211
# [350]	train's multi_logloss: 0.908624	train's f1_weighted: 0.668602	valid's multi_logloss: 1.09878	valid's f1_weighted: 0.512082
# [400]	train's multi_logloss: 0.883834	train's f1_weighted: 0.679602	valid's multi_logloss: 1.09796	valid's f1_weighted: 0.513182
# [450]	train's multi_logloss: 0.861437	train's f1_weighted: 0.693157	valid's multi_logloss: 1.09769	valid's f1_weighted: 0.510338
# [500]	train's multi_logloss: 0.840533	train's f1_weighted: 0.705223	valid's multi_logloss: 1.09768	valid's f1_weighted: 0.506604
# Early stopping, best iteration is:
# [425]	train's multi_logloss: 0.872462	train's f1_weighted: 0.686016	valid's multi_logloss: 1.09747	valid's f1_weighted: 0.514856
# Training until validation scores don't improve for 100 rounds.
# [50]	train's multi_logloss: 1.17814	train's f1_weighted: 0.295874	valid's multi_logloss: 1.20358	valid's f1_weighted: 0.265329
# [100]	train's multi_logloss: 1.10134	train's f1_weighted: 0.518988	valid's multi_logloss: 1.15098	valid's f1_weighted: 0.466527
# [150]	train's multi_logloss: 1.04651	train's f1_weighted: 0.585168	valid's multi_logloss: 1.12059	valid's f1_weighted: 0.503305
# [200]	train's multi_logloss: 1.00595	train's f1_weighted: 0.612593	valid's multi_logloss: 1.10353	valid's f1_weighted: 0.515493
# [250]	train's multi_logloss: 0.972003	train's f1_weighted: 0.627718	valid's multi_logloss: 1.09448	valid's f1_weighted: 0.512849
# [300]	train's multi_logloss: 0.942559	train's f1_weighted: 0.64505	valid's multi_logloss: 1.09048	valid's f1_weighted: 0.514239
# [350]	train's multi_logloss: 0.916371	train's f1_weighted: 0.657678	valid's multi_logloss: 1.08786	valid's f1_weighted: 0.522391
# [400]	train's multi_logloss: 0.892094	train's f1_weighted: 0.671675	valid's multi_logloss: 1.08665	valid's f1_weighted: 0.519062
# [450]	train's multi_logloss: 0.869502	train's f1_weighted: 0.68809	valid's multi_logloss: 1.08659	valid's f1_weighted: 0.521689
# [500]	train's multi_logloss: 0.848231	train's f1_weighted: 0.702864	valid's multi_logloss: 1.08652	valid's f1_weighted: 0.518866
# Early stopping, best iteration is:
# [418]	train's multi_logloss: 0.883874	train's f1_weighted: 0.677064	valid's multi_logloss: 1.08662	valid's f1_weighted: 0.523995

# %%
mean_pread = np.mean(all_preads,axis=0)
cols = ['Excellent ratio','Good ratio','Pass ratio','Fail ratio']

sub_prob  = pd.DataFrame(mean_pread,columns=cols)
len(sub_prob),len(id_test)
sub_prob['Group'] = id_test

sub_prob['Group'] = sub_prob['Group'].map(int)
sub_prob = sub_prob.groupby([ 'Group'])[cols].median().reset_index()

sub_prob.to_csv('../logs/lgb_fisrt.csv',index=False)

# %%
all_preads[0][0]
# Out:
# array([0.47934167, 0.26417681, 0.19051911, 0.06596241])

# %%
features
# Out:
# ['Parameter1',
#  'Parameter10',
#  'Parameter2',
#  'Parameter3',
#  'Parameter4',
#  'Parameter5',
#  'Parameter6',
#  'Parameter7',
#  'Parameter8',
#  'Parameter9']
